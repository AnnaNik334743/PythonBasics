# %% [markdown]
# # Intro

# %% [markdown]
# Данное задание представляет из себя вводный тест на базовые знания Python и алгоритмических подходов к решению задач.
#
# Задание состоит из множества подзадач. Они представляют собой ячейки с кодом, который необходимо дописать. Задания не обязательно решать последовательно. По-возможности старайтесь дополнять ваш код комментариями.
#
# Вам необходимо сделать как можно больше. Не переживайте, если что-то не получится! Это просто оценка ваших знаний, чтобы получить понимание, в каком направлении двигаться дальше. Удачи!

# %% [markdown]
# Необходимые импорты.

# %%
import math
import random
import re
import itertools
import datetime
import typing as tp

# %% [markdown]
# # Арифметика. Функции для работы с числами

# %% [markdown]
# ### 1

# %% [markdown]
# Функция получает на вход трёхзначное число. По этому числу строится новое число по следующим правилам.
#
# 1.  Перемножаются отдельно первая и вторая цифры, а также вторая и третья цифры.
#
# 2.  Полученные два числа записываются друг за другом в порядке невозрастания без разделителей.
#
# Напишите функцию, реализующую данную логику.

# %%
def alter_num(num: int) -> int:
    assert(len(str(num)) == 3)
    # PUT YOUR CODE HERE

# %% [markdown]
# ### 2

# %% [markdown]
# Напишите функцию для перевода числа из любой системы счисления в любую другую. Будем считать, что на вход всегда подаются целые неотрицательные числа, причем основания систем счисления лежат в диапазоне [2; 36].

# %%
def convert_base(num, to_base: int=10, from_base: int=10) -> str:
    alphabet = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    # PUT YOUR CODE HERE

# %% [markdown]
# ### 3

# %% [markdown]
# Для проведения эксперимента создаются изображения, содержащие случайные наборы цветных пикселей. Размер изображения  — width x height пикселей, при сохранении изображения каждый пиксель кодируется одинаковым числом битов, все коды пикселей записываются подряд, методы сжатия не используются. Размер файла не должен превышать max_kb Кбайт, при этом service_info_kb Кбайт необходимо выделить для служебной информации. Какое максимальное количество различных цветов и оттенков можно использовать в изображении? Реализуйте функцию.

# %%
def how_many_colors(width: int=640, height: int=480, max_kb: int=280, service_info_kb: int=40) -> int:
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(how_many_colors() == 64)

# %% [markdown]
# # Условный оператор. Логические операции

# %% [markdown]
# ### 1

# %% [markdown]
# Допишите простую функцию-калькулятор, используя конструкцию if-elif-else. Не забудьте проверять, что на ноль делить нельзя.

# %%
def calculator(operation: str, num1: float, num2: float) -> float:
    assert(operation in ['-', '+', '*', '/', '^'])
    # PUT YOUR CODE HERE

# %% [markdown]
# ### 2

# %% [markdown]
# Предположим, что вы разрабатываете систему проверки входов-выходов сотрудников в организации в рамках базы данных. Для каждой новой приходящей на вход записи перед добавлением в базу вы проверяете, что запись корректна. Как именно? Вы смотрите на последнюю (самую позднюю) имеющуюся запись для данного сотрудника и сверяете время. Пусть вам дана последняя запись (или None в случае отсутствия таковой) и новая запись. Напишите функцию, возвращающую true, если добавляемая запись корректна и false иначе.
#
# Логика работы функции: если новая запись – вход, то последняя запись должна либо отсутствовать, либо быть выходом. Иначе последняя запись должна быть входом. Также время добавляемой записи должно быть больше времени последней записи и быть меньше или равно текущему времени.

# %%
def is_correct(last_record, new_record) -> bool:
    current_time = datetime.datetime.now()
    new_record_is_exit, new_record_time = new_record
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(not is_correct((True, datetime.datetime(2021, 1, 1, 10, 0, 0)), (True, datetime.datetime(2021, 1, 1, 10, 0, 0))))
assert(is_correct((True, datetime.datetime(2021, 1, 1, 10, 0, 0)), (False, datetime.datetime(2021, 1, 1, 11, 0, 0))))
assert(not is_correct(None, (True, datetime.datetime(2021, 1, 1, 10, 0, 0))))
assert(is_correct(None, (False, datetime.datetime(2021, 1, 1, 10, 0, 0))))
assert(is_correct((False, datetime.datetime(2023, 1, 1, 10, 0, 0)), (True, datetime.datetime.now())))
assert(not is_correct((False, datetime.datetime.now()), (True, datetime.datetime(2024, 1, 1, 10, 0, 0))))

# %% [markdown]
# # Циклы

# %% [markdown]
# ### 1

# %% [markdown]
# Пусть M(N)  — произведение 5 наименьших различных натуральных делителей натурального числа N, не считая единицы. Если у числа N меньше 5 таких делителей, то M(N) считается равным нулю.

# %%
def M(n: int) -> int:
    assert(n > 0)
    # PUT YOUR CODE HERE

# %% [markdown]
# Найдите 5 наименьших натуральных чисел, превышающих 200 000 000, для которых 0 < M(N) < N. В ответе запишите найденные значения M(N).

# %%
# PUT YOUR CODE HERE

# %% [markdown]
# Ответ: 1728, 21632, 1260, 1152, 4127787.

# %% [markdown]
# ### 2

# %% [markdown]
# Напишите процедуру, которая ищет среди целых чисел, принадлежащих числовому отрезку [a; b], простые числа. Процедура должна печатать все найденные простые числа в порядке возрастания.

# %%
def is_prime(num: int) -> bool:
    # PUT YOUR CODE HERE


def find_prime_numbers(a: int=5, b: int=9) -> None:
    # PUT YOUR CODE HERE

# %% [markdown]
# find_prime_numbers() с параметрами по умолчанию должна напечатать 5 и 7.

# %% [markdown]
# ### 3

# %% [markdown]
# Реализуйте алгоритм Евклида для поиска НОД. Используйте цикл while.

# %%
def gcd(num1: int, num2: int) -> int:
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(gcd(12, 15) == 3)
assert(gcd(3, 7) == 1)

# %% [markdown]
# # Рекурсия

# %% [markdown]
# ### 1

# %% [markdown]
# Алгоритм вычисления значения функции F(n), где n  — натуральное число, задан следующими соотношениями:
#
# F(n) = 1 при n ≤ 2;
#
# F(n) = F(n − 1) + 2 * F(n − 2) при n > 2.
#
# Реализуйте данную функцию.

# %%
def F(n):
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(F(7) == 43)

# %% [markdown]
# # Типы данных. Строки

# %% [markdown]
# ### 1

# %% [markdown]
# Дана строка. Требуется проверить, является ли она палиндромом (то есть читается одинаково с обеих строн). Учтите, что регистр не имеет значения.

# %%
def is_palindrom(s: str) -> bool:
    # PUT YOUR CODE HERE

# %% [markdown]
# ### 2

# %% [markdown]
# Напишите функцию, выводящую число с заданной точностью. Используйте методы форматирования строк.

# %%
def float_with_precision(num: float, precision: int) -> str:
    # PUT YOUR CODE HERE

# %% [markdown]
# ### 3

# %% [markdown]
# На вход подается строка из слов, разделенных точкой с запятой. Ваша функция должна возвращать слово максимальной длины, в котором, начиная с третьего знака (нумерация с 1), встречается буква f. Если такого слова нет, нужно вернуть пустую строку. В решении используйте срезы, lambda-функции, также можно воспользоваться конструкцией filter.

# %%
def longest_word_with_m(s: str) -> str:
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(longest_word_with_m("hello, fridge, amazing, flat, beautiful, astonishing") == "beautiful")
assert(longest_word_with_m("hello, fridge, amazing, fat") == "")

# %% [markdown]
# ### 4

# %% [markdown]
# Дана последовательность символов, состоящая только из букв XYZ без пробелов. Ваша задача - найти самую длинную подпоследовательность, состояющую из повторов комбинации символов XYZ. Последняя группа может входить не полностью.
#
# Напишите регулярное выражение, позволяющее это сделать.

# %%
regex = r"# PUT YOUR CODE HERE"

# %% [markdown]
# # Типы данных. Списки

# %% [markdown]
# ### 1

# %% [markdown]
# Нужно сгруппировать значения values в список, состоящий из списков по n элементов. Используйте списковые включения.

# %%
def group(values: tp.List[T], n: int) -> tp.List[tp.List[T]]:
    assert(len(values) % n == 0)
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(group([1,2,3,4], 2) == [[1, 2], [3, 4]])
assert(group([1,2,3,4,5,6,7,8,9], 3) == [[1, 2, 3], [4, 5, 6], [7, 8, 9]])

# %% [markdown]
# ### 2

# %% [markdown]
# Дана матрица. Будем считать позицию пустой, если она представлена символом точки. Ваша задача - найти первую пустую позицию в матрице и вернуть её координаты. Если такой позиции нет, нужно возвращать None.

# %%
def find_empty_positions(grid: tp.List[tp.List[str]]) -> tp.Optional[tp.Tuple[int, int]]:
    # PUT YOUR CODE HERE

# %%
# sanity check

assert(find_empty_positions([['1', '2', '.'], ['4', '5', '6'], ['7', '8', '9']]) == (0, 2))
assert(find_empty_positions([['1', '2', '3'], ['4', '.', '6'], ['7', '8', '9']]) == (1, 1))

# %% [markdown]
# # Типы данных. Множества

# %% [markdown]
# ### 1

# %% [markdown]
# Вы с другом хотите посмотреть фильм, но выбрать его так, чтобы вам обоим было интересно. Вы оба составили списсок нравящихся вам фильмов (возможно, с повторениями). Напишите функцию, которая определит, какие фильмы нравятся вам обоим, и выведет список их уникальных названий.

# %%
def get_films(the_films_i_like: tp.List[str], the_films_my_friend_likes: tp.List[str]) -> tp.List[str]:
    # PUT YOUR CODE HERE

# %% [markdown]
# # Типы данных. Словари

# %% [markdown]
# ### 1

# %% [markdown]
# В настольной игре Скрабл (Scrabble) каждая буква имеет определенную ценность. В случае с английским алфавитом очки распределяются так:
#
# A, E, I, O, U, L, N, S, T, R – 1 очко;
#
# D, G – 2 очка;
#
# B, C, M, P – 3 очка;
#
# F, H, V, W, Y – 4 очка;
#
# K – 5 очков;
#
# J, X – 8 очков;
#
# Q, Z – 10 очков.
#
# Напишите программу, которая вычисляет стоимость введенного пользователем слова.

# %%
def scrabble(s: str) -> int:
    # PUT YOUR CODE HERE

# %% [markdown]
# # Файлы

# %% [markdown]
# ### 1

# %% [markdown]
# Решите данное задание https://inf-ege.sdamgia.ru/problem?id=27891. Напишите программу, считывающую данные из файлов и реализующую необходимую логику. Запишите ответ в файл answer.txt. Если не получится решить задачу - ничего страшного. Главное, продемонстрируйте, что вы можете прочитать файл, а также записать в него.
#
# Важно: для работы с файлами лучше всего использовать конструкцию with open().

# %%
# PUT YOUR CODE HERE
